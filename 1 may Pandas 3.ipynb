# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\hardi\\OneDrive - wipro\\Desktop\\datasets\\placement - placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 31  5.92          7.02       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
i = df.ndim     ## number of axes ( it is 2)
i
# Out:
# 2

# %%
top_left_corner_df = df.iloc[:4 , :3]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3 , ['cgpa' , 'placed']]    ## in this range will be counted from 1 ,2 ,3 but not in iloc
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
t = df.shape      # shape = n(rows) , n(columns)
t
# Out:
# (100, 3)

# %%
d = df.size      # row count * column count
d
# Out:
# 300

# %%
a = df.values       ## get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score')   ## in sort_values --> we can arrange the values in ascending order.(small to big)
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r = df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x = df.astype(int)    ## type conversation

df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df['resume_score'] = df['resume_score'].add(5)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12         11.52       1
# 1     10         10.17       0
# 2     12         13.86       1
# 3     10         12.27       1
# 4     11         12.30       1
# ..   ...           ...     ...
# 95    10         11.38       0
# 96    12         12.76       1
# 97    10         12.78       0
# 98    12         10.63       1
# 99    10         11.61       0
#
# [100 rows x 3 columns]

# %%
df['placed'] = df['placed'].add(6)
df
# Out:
#     cgpa  resume_score  placed
# 0     12         11.52       7
# 1     10         10.17       6
# 2     12         13.86       7
# 3     10         12.27       7
# 4     11         12.30       7
# ..   ...           ...     ...
# 95    10         11.38       6
# 96    12         12.76       7
# 97    10         12.78       6
# 98    12         10.63       7
# 99    10         11.61       6
#
# [100 rows x 3 columns]

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            13.00
# resume_score    14.06
# placed           7.00
# dtype: float64

# %%
q = df.min()
q
# Out:
# cgpa            9.00
# resume_score    9.95
# placed          6.00
# dtype: float64

# %% [markdown]
# ## Mean

# %%
# x = 1,2,3,4,5
# mean = 1+2+3+4+5/5  = 15/5 = 3

# %%
r = df['cgpa'].mean()
r
# Out:
# 10.47

# %%
s = df['cgpa'].median()
s
# Out:
# 10.0

# %%
w = df.mean()
w
# Out:
# cgpa            10.4700
# resume_score    11.9305
# placed           6.5000
# dtype: float64

# %%
s = df.sum()
s
# Out:
# cgpa            1047.00
# resume_score    1193.05
# placed           650.00
# dtype: float64

# %%
g = df.filter(items = ['cgpa' , 'placed'])
g
# df[['cgpa' , 'placed']]   ## second method for filtering
# Out:
#     cgpa  placed
# 0     12       7
# 1     10       6
# 2     12       7
# 3     10       7
# 4     11       7
# ..   ...     ...
# 95    10       6
# 96    12       7
# 97    10       6
# 98    12       7
# 99    10       6
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6] , axis = 0)   ## axis = 0 means row wise operation.
s
# Out:
#    cgpa  resume_score  placed
# 5    12         11.19       7
# 6     9         12.09       6

# %%
df.loc[3:6 , ['cgpa' , 'resume_score' , 'placed']]
# Out:
#    cgpa  resume_score  placed
# 3    10         12.27       7
# 4    11         12.30       7
# 5    12         11.19       7
# 6     9         12.09       6

# %%
df.iloc[3:6 , [0,1,2]]
# Out:
#    cgpa  resume_score  placed
# 3    10         12.27       7
# 4    11         12.30       7
# 5    12         11.19       7

# %%
s = df.to_dict()   ## save in dictionary
s
# Out:
# {'cgpa': {0: 12,
#   1: 10,
#   2: 12,
#   3: 10,
#   4: 11,
#   5: 12,
#   6: 9,
#   7: 10,
#   8: 10,
#   9: 11,
#   10: 10,
#   11: 9,
#   12: 10,
#   13: 12,
#   14: 11,
#   15: 12,
#   16: 12,
#   17: 11,
#   18: 9,
#   19: 10,
#   20: 9,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 12,
#   25: 11,
#   26: 10,
#   27: 9,
#   28: 11,
#   29: 10,
#   30: 11,
#   31: 9,
#   32: 9,
#   33: 12,
#   34: 12,
#   35: 12,
#   36: 12,
#   37: 13,
#   38: 10,
#   39: 11,
#   40: 12,
#   41: 12,
#   42: 10,
#   43: 12,
#   44: 9,
#   45: 12,
#   46: 9,
#   47: 11,
#   48: 9,
#   49: 9,
#   50: 12,
#   51: 10,
#   52: 9,
#   53: 10,
#   54: 9,
#   55: 10,
#   56: 10,
#   57: 10,
#   58: 10,
#   59: 9,
#   60: 9,
#   61: 10,
#   62: 9,
#   63: 12,
#   64: 11,
#   65: 10,
#   66: 12,
#   67: 10,
#   68: 10,
#   69: 12,
#   70: 11,
#   71: 11,
#   72: 11,
#   73: 9,
#   74: 9,
#   75: 10,
#   76: 13,
#   77: 9,
#   78: 9,
#   79: 9,
#   80: 11,
#   81: 10,
#   82: 11,
#   83: 11,
#   84: 9,
# ...

# %%
p = df.to_string()   ## save in string
p
# Out:
# '    cgpa  resume_score  placed\n0     12         11.52       7\n1     10         10.17       6\n2     12         13.86       7\n3     10         12.27       7\n4     11         12.30       7\n5     12         11.19       7\n6      9         12.09       6\n7     10         11.29       6\n8     10         11.71       6\n9     11         12.12       7\n10    10         11.35       6\n11     9         11.54       6\n12    10         12.01       6\n13    12         10.09       7\n14    11         11.25       7\n15    12         10.93       7\n16    12         12.64       7\n17    11         13.71       7\n18     9         10.88       6\n19    10         13.11       7\n20     9         13.06       6\n21    10         12.64       6\n22    10         10.77       6\n23    10         12.13       6\n24    12         11.18       7\n25    11         10.68       7\n26    10         11.47       6\n27     9         11.15       6\n28    11         12.67       7\n29    10         12.30       6\n30   
# ...

# %%
e = df.to_csv("path location")

# %%
idx = df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = df.columns[0]     ## first column label
label
# Out:
# 'cgpa'

# %%
p = df.columns.tolist()   ## list of column labels
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q = df.columns.values     ## array of column lables
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df.rename(columns = {'cgpa' : 'updated_cgpa',
             'resume_score' : 'semester_marks'})   ## how to rename a column
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             12           11.52       7
# 1             10           10.17       6
# 2             12           13.86       7
# 3             10           12.27       7
# 4             11           12.30       7
# ..           ...             ...     ...
# 95            10           11.38       6
# 96            12           12.76       7
# 97            10           12.78       6
# 98            12           10.63       7
# 99            10           11.61       6
#
# [100 rows x 3 columns]

# %%
df['Cgpa'] = df['cgpa'].astype(int)  ## here create a new column.

# %%
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0     12         11.52       7    12
# 1     10         10.17       6    10
# 2     12         13.86       7    12
# 3     10         12.27       7    10
# 4     11         12.30       7    11
# ..   ...           ...     ...   ...
# 95    10         11.38       6    10
# 96    12         12.76       7    12
# 97    10         12.78       6    10
# 98    12         10.63       7    12
# 99    10         11.61       6    10
#
# [100 rows x 4 columns]

# %% [markdown]
# ## now we have to delete that column

# %%
a = df.drop(columns = ['Cgpa' , 'placed'])
a
# Out:
#     cgpa  resume_score
# 0     12         11.52
# 1     10         10.17
# 2     12         13.86
# 3     10         12.27
# 4     11         12.30
# ..   ...           ...
# 95    10         11.38
# 96    12         12.76
# 97    10         12.78
# 98    12         10.63
# 99    10         11.61
#
# [100 rows x 2 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0     12         11.52       7    12
# 1     10         10.17       6    10
# 2     12         13.86       7    12
# 3     10         12.27       7    10
# 4     11         12.30       7    11
# ..   ...           ...     ...   ...
# 95    10         11.38       6    10
# 96    12         12.76       7    12
# 97    10         12.78       6    10
# 98    12         10.63       7    12
# 99    10         11.61       6    10
#
# [100 rows x 4 columns]

# %%
df = df.drop(columns = ['Cgpa'])
df
# Out:
#     cgpa  resume_score  placed
# 0     12         11.52       7
# 1     10         10.17       6
# 2     12         13.86       7
# 3     10         12.27       7
# 4     11         12.30       7
# ..   ...           ...     ...
# 95    10         11.38       6
# 96    12         12.76       7
# 97    10         12.78       6
# 98    12         10.63       7
# 99    10         11.61       6
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12         11.52       7
# 1     10         10.17       6
# 2     12         13.86       7
# 3     10         12.27       7
# 4     11         12.30       7
# ..   ...           ...     ...
# 95    10         11.38       6
# 96    12         12.76       7
# 97    10         12.78       6
# 98    12         10.63       7
# 99    10         11.61       6
#
# [100 rows x 3 columns]

# %%
df['New'] = df['cgpa'].where(df['cgpa']>9 , other=0)

# %%
df.sample(8)
# Out:
#     cgpa  resume_score  placed  New
# 28    11         12.67       7   11
# 50    12         11.74       7   12
# 0     12         11.52       7   12
# 83    11         13.08       7   11
# 66    12         13.02       7   12
# 79     9         12.28       6    0
# 9     11         12.12       7   11
# 10    10         11.35       6   10

# %% [markdown]
# ## Make Notes

# %%
# for df merging and concatenating
