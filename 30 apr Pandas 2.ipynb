# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\hardi\\OneDrive - wipro\\Desktop\\datasets\\covid_toy - covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %% [markdown]
# ## top 5 data

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.head(1)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No

# %% [markdown]
# ## bottom 5 data

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.tail(2)
# Out:
#     age  gender  fever   cough     city has_covid
# 98    5  Female   98.0  Strong   Mumbai        No
# 99   10  Female   98.0  Strong  Kolkata       Yes

# %% [markdown]
# ## Random indexed data

# %%
df.sample()
# Out:
#     age gender  fever   cough     city has_covid
# 73   34   Male   98.0  Strong  Kolkata       Yes

# %%
df.sample(4)
# Out:
#     age  gender  fever   cough       city has_covid
# 79   48  Female  103.0    Mild    Kolkata       Yes
# 54   60  Female   99.0    Mild     Mumbai       Yes
# 62   56  Female  104.0  Strong  Bangalore       Yes
# 65   69  Female  102.0    Mild  Bangalore        No

# %%
df = pd.read_csv("C:\\Users\\hardi\\OneDrive - wipro\\Desktop\\datasets\\placement - placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()      ## statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()     ## data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
# there are two methods which we can extract the data.

# (1). iloc  --> [row_range , column_range]
# (2). loc  --> [row_range , column_names].

# %%
top_left_corner_df = df.iloc[:4 , :3]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3 , ['cgpa' , 'placed']]    ## in this range will be counted from 1 ,2 ,3 but not in iloc
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty   ## it returns true if there any missing data in df otherwise return false.
b
# Out:
# False

# %%
df.isnull().sum()   ## for check missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()   ##for remove missing row
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv("C:\\Users\\hardi\\OneDrive - wipro\\Desktop\\datasets\\flipkart.csv")

# %%
df
# Out:
#                                                 Model  Ratings  \
# 0                  Nothing Phone (3a) (Black, 128 GB)      4.5
# 1       Tecno Pova 6 Neo 5G (Midnight Shadow, 128 GB)      4.2
# 2               Motorola G85 5G (Olive Green, 128 GB)      4.4
# 3                     POCO C75 5G (Aqua Bliss, 64 GB)      4.3
# 4              Nothing Phone (3a) Pro (Black, 256 GB)      4.5
# 5            Motorola g45 5G (Brilliant Blue, 128 GB)      4.3
# 6                   vivo T4 5G (Phantom Grey, 256 GB)      4.8
# 7                POCO C75 5G (Silver Stardust, 64 GB)      4.3
# 8         SAMSUNG Galaxy F06 5G (Bahama Blue, 128 GB)      4.2
# 9                  vivo T4 5G (Emerald Blaze, 256 GB)      4.6
# 10  realme C63 5G Charger in the Box (Forest Green...      4.5
# 11          Motorola g45 5G (Brilliant Green, 128 GB)      4.3
# 12                vivo T4x 5G (Pronto Purple, 128 GB)      4.5
# 13                 vivo T4 5G (Emerald Blaze, 128 GB)      4.6
# ...

# %%
df.tail()
# Out:
#                                                 Model  Ratings  \
# 22             Motorola G85 5G (Viva Magenta, 128 GB)      4.4
# 23  OPPO K12x 5G with 45W SUPERVOOC Charger In-The...      4.5
# 24                                                NaN      NaN
# 25                                                NaN      NaN
# 26                                                NaN      NaN
#
#            Ratings 2        reviews  \
# 22  1,69,368 Ratings  9,053 Reviews
# 23  1,60,398 Ratings  5,775 Reviews
# 24               NaN            NaN
# 25               NaN            NaN
# 26               NaN            NaN
#
#                                          Storage  \
# 22                         8 GB RAM | 128 GB ROM
# 23  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
#
# ...

# %%
df.head()
# Out:
#                                            Model  Ratings         Ratings 2  \
# 0             Nothing Phone (3a) (Black, 128 GB)      4.5    15,014 Ratings
# 1  Tecno Pova 6 Neo 5G (Midnight Shadow, 128 GB)      4.2       262 Ratings
# 2          Motorola G85 5G (Olive Green, 128 GB)      4.4  1,69,368 Ratings
# 3                POCO C75 5G (Aqua Bliss, 64 GB)      4.3    40,083 Ratings
# 4         Nothing Phone (3a) Pro (Black, 256 GB)      4.5     2,726 Ratings
#
#          reviews                                       Storage  \
# 0  1,545 Reviews                         8 GB RAM | 128 GB ROM
# 1     11 Reviews  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 2  9,053 Reviews                         8 GB RAM | 128 GB ROM
# 3  2,161 Reviews   4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 4    328 Reviews                         8 GB RAM | 256 GB ROM
#
#                                  Display  \
# 0   17.2 cm (6.77 inch) Full HD+ Display
# 1           16.94 cm (6.67 inch) Display
# ...

# %%
df.columns
# Out:
# Index(['Model', 'Ratings', 'Ratings 2', 'reviews', 'Storage', 'Display',
#        'Camera', 'Battery', 'Processor', 'Insurance', 'Discounted Price',
#        'Actual Price', 'Bank Offer'],
#       dtype='object')

# %%
df.sample()
# Out:
#                                            Model  Ratings    Ratings 2  \
# 1  Tecno Pova 6 Neo 5G (Midnight Shadow, 128 GB)      4.2  262 Ratings
#
#       reviews                                       Storage  \
# 1  11 Reviews  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
#
#                         Display                                Camera  \
# 1  16.94 cm (6.67 inch) Display  108MP Rear Camera | 8MP Front Camera
#
#             Battery                    Processor  \
# 1  5000 mAh Battery  Dimensity 6300 5G Processor
#
#                                 Insurance Discounted Price Actual Price  \
# 1  1 Year Manufacturer Warranty for Phone          ₹11,999      ₹15,999
#
#         Bank Offer
# 1  Off on Exchange
